# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex1s-sys/Probabilidad-y-estadistica/blob/main/Unidad1/Practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Unidad 1
# #Practica 5:
# #Docente: Dr Jose Gabriel Rodriguez Rivas
# Alumno: Erick Alexis Flores Reyes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot

# %%
covid = pd.read_csv("20-06-30-COVID19MEXICO - codificado.csv", encoding = "ISO-8859-1", on_bad_lines='skip')
# Out:
# /tmp/ipython-input-3350967460.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv("20-06-30-COVID19MEXICO - codificado.csv", encoding = "ISO-8859-1", on_bad_lines='skip')

# %%
covid.head()
# Out:
#    ï»¿ORIGEN  SECTOR    SEXO ENTIDAD_NAC  TIPO_PACIENTE FECHA_INGRESO  \
# 0          1       4  Hombre   Zacatecas  Hospitalizado    27/03/2020
# 1          1      12  Hombre   Zacatecas  Hospitalizado    06/04/2020
# 2          1      12   Mujer   Zacatecas  Hospitalizado    15/04/2020
# 3          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
# 4          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
#
#   FECHA_SINTOMAS   FECHA_DEF INTUBADO NEUMONIA  ... EPOC ASMA INMUSUPR  \
# 0     27/03/2020  9999-99-99       No       No  ...   No   No       No
# 1     02/04/2020  9999-99-99       No       Si  ...   No   No       No
# 2     12/04/2020  9999-99-99       No       Si  ...   No   No       Si
# 3     08/05/2020  9999-99-99       Si       No  ...   No   No       No
# 4     08/05/2020  9999-99-99       Si       No  ...   No   No       No
#
#   HIPERTENSION CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO RESULTADO UCI
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472980 entries, 0 to 472979
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ï»¿ORIGEN       472980 non-null  int64
#  1   SECTOR          472980 non-null  int64
#  2   SEXO            472980 non-null  object
#  3   ENTIDAD_NAC     472980 non-null  object
#  4   TIPO_PACIENTE   472980 non-null  object
#  5   FECHA_INGRESO   472980 non-null  object
#  6   FECHA_SINTOMAS  472980 non-null  object
#  7   FECHA_DEF       472979 non-null  object
#  8   INTUBADO        472979 non-null  object
#  9   NEUMONIA        472979 non-null  object
#  10  EDAD            472979 non-null  object
#  11  EMBARAZO        472978 non-null  object
#  12  DIABETES        472978 non-null  object
#  13  EPOC            472978 non-null  object
#  14  ASMA            472978 non-null  object
#  15  INMUSUPR        472978 non-null  object
# ...
