# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex1s-sys/Probabilidad-y-estadistica/blob/main/Unidad3/Probabilidad_u3_Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
# ##Unidad 3
# ## Facilitador:Jose Gabriel Rodriguez Rivas
# ##Alumno:Erick Alexis Flores Reyes
# ## **Programa 2: Valor esperado**

# %%
x=[5,6,7,8,9,10] #Valores posibles de la variable aleatoria
p=[0.05,0.10,0.20, 0.30, 0.25,0.10 ] #Probabilidades correspondientes
# Inicializar una variable para acumular la suma
valor_esperado=0

#Recorrer los valores y sus probabilidades
for i in range(len(x)):
  xi=x[i] # Valor de la variable aleatoria
  pi=p[i] # Probabilidad de ese valor
  producto=xi*pi #Multiplicar valor por su probabilidad
  valor_esperado +=producto
  #Mostrar cada paso
  print(f"x = {xi}, p = {pi}, xi*pi = {producto:.2f}")

  #Mostrar resultado final
  print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.05, xi*pi = 0.25
#
# Valor esperado (Esperanza): 0.25
# x = 6, p = 0.1, xi*pi = 0.60
#
# Valor esperado (Esperanza): 0.85
# x = 7, p = 0.2, xi*pi = 1.40
#
# Valor esperado (Esperanza): 2.25
# x = 8, p = 0.3, xi*pi = 2.40
#
# Valor esperado (Esperanza): 4.65
# x = 9, p = 0.25, xi*pi = 2.25
#
# Valor esperado (Esperanza): 6.90
# x = 10, p = 0.1, xi*pi = 1.00
#
# Valor esperado (Esperanza): 7.90
