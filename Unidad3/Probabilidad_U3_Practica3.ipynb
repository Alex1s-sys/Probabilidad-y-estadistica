# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex1s-sys/Probabilidad-y-estadistica/blob/main/Unidad3/Probabilidad_U3_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
# ##Unidad 3
# ## Facilitador:Jose Gabriel Rodriguez Rivas
# ##Alumno:Erick Alexis Flores Reyes
# ## **Programa 3: Varianza y desviacion**

# %%
import math

# %%
x=[5,6,7,8,9,10]
p=[0.05,0.10, 0.20, 0.30, 0.25, 0.10]

#Calcular E(x)
esperanza=0
for i in range(len(x)):
  esperanza += x[i] * p[i]

#Calcular E(X elevado al cuadrado)
esperanza_cuadrado = 0
for i in range(len(x)):
   esperanza_cuadrado += (x[i] ** 2) * p[i]

#Calcular varianza y desviacion estandar (moved outside the loop)
varianza = esperanza_cuadrado - (esperanza ** 2)
desviacion = math.sqrt(varianza)

#Mostrar resultados (moved outside the loop)
print(f"E(X)= {esperanza:.2F}")
print(f"E(X^2)= {esperanza_cuadrado:.2F}")
print(f"Varianza= {varianza:.2F}")
print(f"Desviacion estandar= {desviacion:.2F}")
# Out:
# E(X)= 7.90
# E(X^2)= 64.10
# Varianza= 1.69
# Desviacion estandar= 1.30
