# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex1s-sys/Probabilidad-y-estadistica/blob/main/Unidad4/Probabilidad_U4_Tstudent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
# ##Unidad 4
# ## Facilitador:Jose Gabriel Rodriguez Rivas
# ##Alumno:Erick Alexis Flores Reyes
# ## **Distribucion T de student**

# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt
# Datos de la muestra
data = np.array ([118, 125, 130, 128, 122, 135, 126, 132, 129, 120, 127, 124])
n = len(data)
media np.mean(data)
desv_std np.std(data, ddof=1) # desviación estándar muestral (ddof=1)
alpha 0.05 # nivel de significancia (95% de confianza)
dfn1
# Valor crítico de t (dos colas)
t_critico t.ppf(1 alpha/2, df)
# Error estándar
error = t_critico (desv_std / np.sqrt(n))

# %%
# Intervalo de confianza
lim_inf media error
lim_sup media + error
print (f"Media muestral = {media:.2f} mmHg")
print (f"Desviación estándar (desv_std:.2f} mmHg")
print (f"Grados de libertad = {df}")
print (f"Valor crítico t= {t_critico:.3f}")
print (f"Intervalo de confianza 95%: [{lim_inf:.2f}, {lim_sup:.2f}] mmHg")
# Graficar
x = np.linspace(media 3*desv_std, media + 3*desv_std, 200)
yt.pdf((x media) / (desv_std / np.sqrt(n)), df)
